# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

df = pd.read_csv('C:/Users/ramon/OneDrive/Documents/Data Analyst Projects/Movies Analytics/movies.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
len(df)
# Out:
# 7668

# %%
#looking for missing data
print("Column  missing  total missing") 
for columns in df.columns:
    percent_missing = np.mean(df[columns].isnull()) * 100
    total_rows = len(df)
    total_emptyrows = percent_missing * (total_rows / 100)
    print(f'{columns}      {percent_missing:.2f}%      {round(total_emptyrows)}')
print("total rows",len(df))
# Out:
# Column  missing  total missing
# name      0.00%      0
# rating      1.00%      77
# genre      0.00%      0
# year      0.00%      0
# released      0.03%      2
# score      0.04%      3
# votes      0.04%      3
# director      0.00%      0
# writer      0.04%      3
# star      0.01%      1
# country      0.04%      3
# budget      28.31%      2171
# gross      2.46%      189
# company      0.22%      17
# runtime      0.05%      4
# total rows 7668

# %%
df['budget'] = df['budget'].fillna(0).astype('int64')
df['gross'] = df['gross'].fillna(0).astype('int64')
df['votes'] = df['votes'].fillna(0).astype('int64')
df['runtime'] = df['runtime'].fillna(0).astype('int64')

# %%
df.sort_values(by=['gross'],inplace=False, ascending=False).head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime
# 5445  2847246203  Twentieth Century Fox      162
# 7445  2797501328         Marvel Studios      181
# 3045  2201647264  Twentieth Century Fox      194
# 6663  2069521700              Lucasfilm      138
# 7244  2048359754         Marvel Studios      149

# %%
#Plot Budget vs gross

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "grey"}, line_kws={"color": "blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
def correlation(df):

    plt.figure(figsize=(10, 8))

    sns.heatmap(dfcorr, 
            annot=True,
            cmap='RdYlGn',
            center=0,
            linewidths=0.5,
            cbar_kws={"shrink":0.5})

    plt.title("Correlation Matrix")
    plt.show()
correlation(df)

# %%
df_numerized = df

for col in df_numerized.columns:
    if(df_numerized[col].dtype == 'object'):
        df_numerized[col] = df_numerized[col].astype('category')
        df_numerized[col] = df_numerized[col].cat.codes
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score    votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000      1111    2567
# 3   286       4      4  1980      1492    7.7   221000      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000      1054     521
#
#    star  country    budget      gross  company  runtime
# 0  1047       54  19000000   46998772     2319      146
# 1   327       55   4500000   58853106      731      104
# 2  1745       55  18000000  538375067     1540      124
# 3  2246       55   3500000   83453539     1812       88
# 4   410       55   6000000   39846344     1777       98

# %%
plt.figure(figsize=(12, 8))

sns.heatmap(correlation_matrix, 
            annot=True, 
            cmap='coolwarm',
            center=0, 
            linewidths=0.5, 
            cbar_kws={"shrink": 0.5}, 
            vmin=-1, vmax=1)

plt.title("Matriz de Correlación")
plt.show()

# %%
df_cleaned = df.dropna()
corr = df_cleaned.corr()
#table form
corr_pairs = corr.unstack().sort_values(ascending=False)
#delete duplicated corr for a better visual
corr_pairs = corr_pairs[corr_pairs.index.get_level_values(0) < corr_pairs.index.get_level_values(1)]
#delete corr for same columns
corr_pairs = corr_pairs[corr_pairs.index.get_level_values(0) != corr_pairs.index.get_level_values(1)]

high_corr = corr_pairs[(abs(corr_pairs) > 0.7)]
moderate_corr = corr_pairs[(abs(corr_pairs) >= 0.3) & (abs(corr_pairs) <= 0.7)]
low_corr = corr_pairs[(abs(corr_pairs) < 0.3)]

def highlight_corr(val):
    if abs(val) > 0.7:
        return 'color: forestgreen; font-weight: bold'
    elif abs(val) >= 0.3:
        return 'color: green'
    else:
        return 'color: black'

corr_dict = {
    "High correlation (> 0.7)": high_corr,
    "Mid correlation (0.3 - 0.7)": moderate_corr,
    "Low correlation (< 0.3)": low_corr
}

for title, corr_data in corr_dict.items():
    display(HTML(f'<h2 style="color:#585858">{title}</h2>'))
    corr_df = corr_data.to_frame()
    corr_df.columns = ['Correlation']
    corr_styled = corr_df.style.applymap(highlight_corr)
    display(corr_styled)
# Out:
# <h2 style="color:#585858">High correlation (> 0.7)</h2>
# <style type="text/css">
# #T_4cdb1_row0_col0 {
#   color: forestgreen;
#   font-weight: bold;
# }
# </style>
# <table id="T_4cdb1">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4cdb1_level0_col0" class="col_heading level0 col0" >Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4cdb1_level0_row0" class="row_heading level0 row0" >budget</th>
#       <th id="T_4cdb1_level1_row0" class="row_heading level1 row0" >gross</th>
#       <td id="T_4cdb1_row0_col0" class="data row0 col0" >0.750133</td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="color:#585858">Mid correlation (0.3 - 0.7)</h2>
# <style type="text/css">
# #T_efc14_row0_col0, #T_efc14_row1_col0, #T_efc14_row2_col0, #T_efc14_row3_col0, #T_efc14_row4_col0, #T_efc14_row5_col0, #T_efc14_row6_col0 {
#   color: green;
# }
# </style>
# <table id="T_efc14">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efc14_level0_col0" class="col_heading level0 col0" >Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efc14_level0_row0" class="row_heading level0 row0" >gross</th>
#       <th id="T_efc14_level1_row0" class="row_heading level1 row0" >votes</th>
#       <td id="T_efc14_row0_col0" class="data row0 col0" >0.632834</td>
#     </tr>
#     <tr>
#       <th id="T_efc14_level0_row1" class="row_heading level0 row1" >budget</th>
#       <th id="T_efc14_level1_row1" class="row_heading level1 row1" >votes</th>
#       <td id="T_efc14_row1_col0" class="data row1 col0" >0.486862</td>
#     </tr>
#     <tr>
#       <th id="T_efc14_level0_row2" class="row_heading level0 row2" >score</th>
#       <th id="T_efc14_level1_row2" class="row_heading level1 row2" >votes</th>
#       <td id="T_efc14_row2_col0" class="data row2 col0" >0.409182</td>
#     </tr>
#     <tr>
#       <th id="T_efc14_level0_row3" class="row_heading level0 row3" >runtime</th>
#       <th id="T_efc14_level1_row3" class="row_heading level1 row3" >score</th>
#       <td id="T_efc14_row3_col0" class="data row3 col0" >0.398387</td>
#     </tr>
#     <tr>
#       <th id="T_efc14_level0_row4" class="row_heading level0 row4" >budget</th>
#       <th id="T_efc14_level1_row4" class="row_heading level1 row4" >year</th>
#       <td id="T_efc14_row4_col0" class="data row4 col0" >0.309873</td>
#     </tr>
#     <tr>
#       <th id="T_efc14_level0_row5" class="row_heading level0 row5" >runtime</th>
#       <th id="T_efc14_level1_row5" class="row_heading level1 row5" >votes</th>
#       <td id="T_efc14_row5_col0" class="data row5 col0" >0.307074</td>
#     </tr>
#     <tr>
#       <th id="T_efc14_level0_row6" class="row_heading level0 row6" >budget</th>
#       <th id="T_efc14_level1_row6" class="row_heading level1 row6" >genre</th>
#       <td id="T_efc14_row6_col0" class="data row6 col0" >-0.334087</td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="color:#585858">Low correlation (< 0.3)</h2>
# <style type="text/css">
# #T_5af7d_row0_col0, #T_5af7d_row1_col0, #T_5af7d_row2_col0, #T_5af7d_row3_col0, #T_5af7d_row4_col0, #T_5af7d_row5_col0, #T_5af7d_row6_col0, #T_5af7d_row7_col0, #T_5af7d_row8_col0, #T_5af7d_row9_col0, #T_5af7d_row10_col0, #T_5af7d_row11_col0, #T_5af7d_row12_col0, #T_5af7d_row13_col0, #T_5af7d_row14_col0, #T_5af7d_row15_col0, #T_5af7d_row16_col0, #T_5af7d_row17_col0, #T_5af7d_row18_col0, #T_5af7d_row19_col0, #T_5af7d_row20_col0, #T_5af7d_row21_col0, #T_5af7d_row22_col0, #T_5af7d_row23_col0, #T_5af7d_row24_col0, #T_5af7d_row25_col0, #T_5af7d_row26_col0, #T_5af7d_row27_col0, #T_5af7d_row28_col0, #T_5af7d_row29_col0, #T_5af7d_row30_col0, #T_5af7d_row31_col0, #T_5af7d_row32_col0, #T_5af7d_row33_col0, #T_5af7d_row34_col0, #T_5af7d_row35_col0, #T_5af7d_row36_col0, #T_5af7d_row37_col0, #T_5af7d_row38_col0, #T_5af7d_row39_col0, #T_5af7d_row40_col0, #T_5af7d_row41_col0, #T_5af7d_row42_col0, #T_5af7d_row43_col0, #T_5af7d_row44_col0, #T_5af7d_row45_col0, #T_5af7d_row46_col0, #T_5af7d_row47_col0, #T_5af7d_row48_col0, #T_5af7d_row49_col0, #T_5af7d_row50_col0, #T_5af7d_row51_col0, #T_5af7d_row52_col0, #T_5af7d_row53_col0, #T_5af7d_row54_col0, #T_5af7d_row55_col0, #T_5af7d_row56_col0, #T_5af7d_row57_col0, #T_5af7d_row58_col0, #T_5af7d_row59_col0, #T_5af7d_row60_col0, #T_5af7d_row61_col0, #T_5af7d_row62_col0, #T_5af7d_row63_col0, #T_5af7d_row64_col0, #T_5af7d_row65_col0, #T_5af7d_row66_col0, #T_5af7d_row67_col0, #T_5af7d_row68_col0, #T_5af7d_row69_col0, #T_5af7d_row70_col0, #T_5af7d_row71_col0, #T_5af7d_row72_col0, #T_5af7d_row73_col0, #T_5af7d_row74_col0, #T_5af7d_row75_col0, #T_5af7d_row76_col0, #T_5af7d_row77_col0, #T_5af7d_row78_col0, #T_5af7d_row79_col0, #T_5af7d_row80_col0, #T_5af7d_row81_col0, #T_5af7d_row82_col0, #T_5af7d_row83_col0, #T_5af7d_row84_col0, #T_5af7d_row85_col0, #T_5af7d_row86_col0, #T_5af7d_row87_col0, #T_5af7d_row88_col0, #T_5af7d_row89_col0, #T_5af7d_row90_col0, #T_5af7d_row91_col0, #T_5af7d_row92_col0, #T_5af7d_row93_col0, #T_5af7d_row94_col0, #T_5af7d_row95_col0, #T_5af7d_row96_col0 {
#   color: black;
# }
# </style>
# <table id="T_5af7d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5af7d_level0_col0" class="col_heading level0 col0" >Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5af7d_level0_row0" class="row_heading level0 row0" >director</th>
#       <th id="T_5af7d_level1_row0" class="row_heading level1 row0" >writer</th>
#       <td id="T_5af7d_row0_col0" class="data row0 col0" >0.298963</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row1" class="row_heading level0 row1" >budget</th>
#       <th id="T_5af7d_level1_row1" class="row_heading level1 row1" >runtime</th>
#       <td id="T_5af7d_row1_col0" class="data row1 col0" >0.268467</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row2" class="row_heading level0 row2" rowspan="2">gross</th>
#       <th id="T_5af7d_level1_row2" class="row_heading level1 row2" >year</th>
#       <td id="T_5af7d_row2_col0" class="data row2 col0" >0.262391</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level1_row3" class="row_heading level1 row3" >runtime</th>
#       <td id="T_5af7d_row3_col0" class="data row3 col0" >0.244410</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row4" class="row_heading level0 row4" >votes</th>
#       <th id="T_5af7d_level1_row4" class="row_heading level1 row4" >year</th>
#       <td id="T_5af7d_row4_col0" class="data row4 col0" >0.222945</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row5" class="row_heading level0 row5" >gross</th>
#       <th id="T_5af7d_level1_row5" class="row_heading level1 row5" >score</th>
#       <td id="T_5af7d_row5_col0" class="data row5 col0" >0.186392</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row6" class="row_heading level0 row6" >budget</th>
#       <th id="T_5af7d_level1_row6" class="row_heading level1 row6" >company</th>
#       <td id="T_5af7d_row6_col0" class="data row6 col0" >0.186186</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row7" class="row_heading level0 row7" rowspan="2">company</th>
#       <th id="T_5af7d_level1_row7" class="row_heading level1 row7" >gross</th>
#       <td id="T_5af7d_row7_col0" class="data row7 col0" >0.156549</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level1_row8" class="row_heading level1 row8" >votes</th>
#       <td id="T_5af7d_row8_col0" class="data row8 col0" >0.133204</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row9" class="row_heading level0 row9" >budget</th>
#       <th id="T_5af7d_level1_row9" class="row_heading level1 row9" >country</th>
#       <td id="T_5af7d_row9_col0" class="data row9 col0" >0.131848</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row10" class="row_heading level0 row10" >runtime</th>
#       <th id="T_5af7d_level1_row10" class="row_heading level1 row10" >year</th>
#       <td id="T_5af7d_row10_col0" class="data row10 col0" >0.116327</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row11" class="row_heading level0 row11" >score</th>
#       <th id="T_5af7d_level1_row11" class="row_heading level1 row11" >year</th>
#       <td id="T_5af7d_row11_col0" class="data row11 col0" >0.097995</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row12" class="row_heading level0 row12" >company</th>
#       <th id="T_5af7d_level1_row12" class="row_heading level1 row12" >country</th>
#       <td id="T_5af7d_row12_col0" class="data row12 col0" >0.095878</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row13" class="row_heading level0 row13" rowspan="3">country</th>
#       <th id="T_5af7d_level1_row13" class="row_heading level1 row13" >gross</th>
#       <td id="T_5af7d_row13_col0" class="data row13 col0" >0.095413</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level1_row14" class="row_heading level1 row14" >rating</th>
#       <td id="T_5af7d_row14_col0" class="data row14 col0" >0.081991</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level1_row15" class="row_heading level1 row15" >votes</th>
#       <td id="T_5af7d_row15_col0" class="data row15 col0" >0.073625</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row16" class="row_heading level0 row16" >genre</th>
#       <th id="T_5af7d_level1_row16" class="row_heading level1 row16" >rating</th>
#       <td id="T_5af7d_row16_col0" class="data row16 col0" >0.072294</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row17" class="row_heading level0 row17" >rating</th>
#       <th id="T_5af7d_level1_row17" class="row_heading level1 row17" >runtime</th>
#       <td id="T_5af7d_row17_col0" class="data row17 col0" >0.064120</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row18" class="row_heading level0 row18" >budget</th>
#       <th id="T_5af7d_level1_row18" class="row_heading level1 row18" >score</th>
#       <td id="T_5af7d_row18_col0" class="data row18 col0" >0.055665</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row19" class="row_heading level0 row19" >released</th>
#       <th id="T_5af7d_level1_row19" class="row_heading level1 row19" >score</th>
#       <td id="T_5af7d_row19_col0" class="data row19 col0" >0.042788</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row20" class="row_heading level0 row20" >director</th>
#       <th id="T_5af7d_level1_row20" class="row_heading level1 row20" >star</th>
#       <td id="T_5af7d_row20_col0" class="data row20 col0" >0.039015</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row21" class="row_heading level0 row21" >company</th>
#       <th id="T_5af7d_level1_row21" class="row_heading level1 row21" >runtime</th>
#       <td id="T_5af7d_row21_col0" class="data row21 col0" >0.037574</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row22" class="row_heading level0 row22" >rating</th>
#       <th id="T_5af7d_level1_row22" class="row_heading level1 row22" >votes</th>
#       <td id="T_5af7d_row22_col0" class="data row22 col0" >0.033225</td>
#     </tr>
#     <tr>
#       <th id="T_5af7d_level0_row23" class="row_heading level0 row23" rowspan="2">genre</th>
#       <th id="T_5af7d_level1_row23" class="row_head
